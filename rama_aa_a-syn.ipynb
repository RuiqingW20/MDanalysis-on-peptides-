# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('/Users/ruiqingwang/a_syn.xvg', header = None, sep = '\s+')
data.columns = ['phi', 'psi', 'aa']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/rw/zxxg_zl91p538ktxtjh8qnr40000gn/T/ipykernel_57165/987844691.py in <module>
# ----> 1 data = pd.read_csv('/Users/ruiqingwang/a_syn.xvg', header = None, sep = '\s+')
#       2 data.columns = ['phi', 'psi', 'aa']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data
# Out:
#              phi        psi      aa
# 0       -57.4004  -47.30050   ASP-2
# 1       -55.8565  -34.71870   VAL-3
# 2       -70.6616  -47.05750   PHE-4
# 3       -69.5623  -24.06730   MET-5
# 4       -85.9472   -3.65453   LYS-6
# ...          ...        ...     ...
# 260008   61.4853   45.55550  LYS-10
# 260009 -133.0310  177.94100  ALA-11
# 260010 -100.8220  154.84000  LYS-12
# 260011 -146.4310  143.33900  GLU-13
# 260012  117.8640  170.76900  GLY-14
#
# [260013 rows x 3 columns]

# %%
sns.jointplot(x=data["phi"], y=data["psi"], kind='kde')

# %%
from RamachanDraw import fetch,phi_psi,plot

# %%
# plot('/Users/ruiqingwang/rama.pdb', cmap='viridis', alpha=0.75, dpi=100, save=True, show=False, out='plot.png');
# plt.title("Ramachandran plot of a-syn 15")

# %%
list4 = data[data["aa"]=="PHE-4"]
sns.jointplot(x=list4["phi"], y=list4["psi"], kind='kde')
plt.title("PHE-4")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rw/zxxg_zl91p538ktxtjh8qnr40000gn/T/ipykernel_57165/2723365274.py in <module>
# ----> 1 list4 = data[data["aa"]=="PHE-4"]
#       2 sns.jointplot(x=list4["phi"], y=list4["psi"], kind='kde')
#       3 plt.title("PHE-4")
#
# NameError: name 'data' is not defined

# %%
# Out:
# Text(0.5, 1.0, 'PHE-4')

# %%
list2 = data[data["aa"]=="ASP-2"]
list2
# Out:
#              phi      psi     aa
# 0       -57.4004 -47.3005  ASP-2
# 13      -62.3060 -42.3358  ASP-2
# 26      -65.0144 -32.9540  ASP-2
# 39      -75.9077 -34.0174  ASP-2
# 52      -61.8746 -25.1541  ASP-2
# ...          ...      ...    ...
# 259948  -51.2798 -39.2717  ASP-2
# 259961 -104.3570 -20.8485  ASP-2
# 259974  -61.6461 -56.8869  ASP-2
# 259987  -58.1694 -28.7080  ASP-2
# 260000  -63.6815 -24.6081  ASP-2
#
# [20001 rows x 3 columns]

# %%
list2 = data[data["aa"]=="ASP-2"]
list2
sns.jointplot(x=list2["phi"], y=list2["psi"], kind='kde')
plt.title("ASP-2")
# Out:
# Text(0.5, 1.0, 'ASP-2')

# %%
sns.kdeplot(x=list2["phi"], y=list2["psi"], cmap="Blues", shade=True, thresh=0)

plt.title("ASP-2")
plt.show()

# %%
list3 = data[data["aa"]=="VAL-3"]
list3
sns.jointplot(x=list3["phi"], y=list3["psi"], kind='kde')
plt.title("VAL-3")
# Out:
# Text(0.5, 1.0, 'VAL-3')

# %%
list5 = data[data["aa"]=="MET-5"]
list5
sns.jointplot(x=list5["phi"], y=list5["psi"], kind='kde')
plt.title("MET-5")
# Out:
# Text(0.5, 1.0, 'MET-5')

# %%
list6 = data[data["aa"]=="LYS-6"]
list6
sns.jointplot(x=list6["phi"], y=list6["psi"], kind='kde')
plt.title("LYS-6")
# Out:
# Text(0.5, 1.0, 'LYS-6')

# %%
list7 = data[data["aa"]=="GLY-7"]
list7
sns.jointplot(x=list7["phi"], y=list7["psi"], kind='kde')
plt.title("GLY-7")
# Out:
# Text(0.5, 1.0, 'GLY-7')

# %%
list8 = data[data["aa"]=="LEU-8"]
list8
sns.jointplot(x=list8["phi"], y=list8["psi"], kind='kde')
plt.title("LEU-8")
# Out:
# Text(0.5, 1.0, 'LEU-8')

# %%
list9 = data[data["aa"]=="SER-9"]
list9
sns.jointplot(x=list9["phi"], y=list9["psi"], kind='kde')
plt.title("SER-9")
# Out:
# Text(0.5, 1.0, 'SER-9')

# %%
list10 = data[data["aa"]=="LYS-10"]
list10
sns.jointplot(x=list10["phi"], y=list10["psi"], kind='kde')
plt.title("LYS-10")
# Out:
# Text(0.5, 1.0, 'LYS-10')

# %%
list11 = data[data["aa"]=="ALA-11"]
list11
sns.jointplot(x=list11["phi"], y=list11["psi"], kind='kde')
plt.title("ALA-11")
# Out:
# Text(0.5, 1.0, 'ALA-11')

# %%
list12 = data[data["aa"]=="LYS-12"]
list12
sns.jointplot(x=list12["phi"], y=list12["psi"], kind='kde')
plt.title("LYS-12")
# Out:
# Text(0.5, 1.0, 'LYS-12')

# %%
list13 = data[data["aa"]=="GLU-13"]
list13
sns.jointplot(x=list13["phi"], y=list13["psi"], kind='kde')
plt.title("GLU-13")
# Out:
# Text(0.5, 1.0, 'GLU-13')

# %%
list14 = data[data["aa"]=="GLY-14"]
list14
sns.jointplot(x=list14["phi"], y=list14["psi"], kind='kde')
plt.title("GLY-14")
# Out:
# Text(0.5, 1.0, 'GLY-14')
